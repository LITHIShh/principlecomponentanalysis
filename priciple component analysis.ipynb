# %%
missing_data=mydata.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13248\600569532.py in <module>
# ----> 1 missing_data=mydata.isnull()
#       2 for column in missing_data.columns.values.tolist():
#       3     print(column)
#       4     print(missing_data[column].value_counts())
#       5     print("")
#
# NameError: name 'mydata' is not defined

# %%
mydata_selected = mydata[["Company Name", "Sentiment Score", "Sentiment Analysis"]]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
data = pd.read_excel("'output01.xlsx'")

# Encode the categorical variables using one-hot encoding


# Calculate the correlation matrix


# Plot the heatmap
plt.figure(figsize=(30,20))  # Set the figure size to 10 inches wide by 8 inches high
sns.heatmap(corr_matrix, cmap="coolwarm", annot=True)
plt.savefig("heatmap1.png")

plt.show()

# %%
plt.savefig("heatmap.png")

# %%
import pandas as pd

# Load the dataset
df= pd.read_excel("final3.xlsx")

# Drop the 'Headlines' and 'Dates' columns
df = df.drop(['Headlines', 'Dates'], axis=1)

# Pivot the dataframe
transposed_df = df.pivot_table(index=None, columns='Company Name', values=['Sentiment Score', 'Sentiment Analysis'])

# Flatten the multi-index column names
transposed_df.columns = [f"{i}_{j}" for i, j in transposed_df.columns]

# Reset the index to default
transposed_df = transposed_df.reset_index(drop=True)

# Preview the transposed dataframe
print(transposed_df)

# %%
import pandas as pd

# Load the dataset
df= pd.read_excel("final3.xlsx")


# Pivot the dataframe
pivoted_df = df.pivot(index=None, columns='Company Name', values='Sentiment Score')
# Flatten the multi-index column names
transposed_df = pivoted_df.transpose().reset_index()
transposed_df = pivoted_df.transpose()
transposed_df = transposed_df.reset_index()
transposed_df.columns.name = None


# Reset the index to default
transposed_df.columns.name = None

# Preview the transposed dataframe
print(transposed_df)

# %%
import pandas as pd

# Read the Excel file into a pandas DataFrame
df = pd.read_excel('final3.xlsx')

# Save the DataFrame as a CSV file
df.to_csv('bankcsv_file.csv', index=False)

# %%
df=pd.read_csv('bankcsv_file.csv')

# %%
df

# %%
import pandas as pd

dtypes = {'Sentiment Score': float}

# Load the dataset
df = pd.read_csv('bankcsv_file.csv', delimiter=',', dtype=dtypes)



# Load the dataset

# %%
# Pivot the dataframe
transposed_df = df.pivot(index=None, columns='Company Name', values=['Sentiment Score', 'Sentiment Analysis'])

# Flatten the multi-index column names
transposed_df.columns = [f"{i}_{j}" for i, j in transposed_df.columns]

# Reset the index to default
transposed_df = transposed_df.reset_index(drop=True)

# Preview the transposed dataframe
print(transposed_df)

# %%
df.columns("Sentiment Score")

# %%
import pandas as pd

# load your csv file into a pandas dataframe
df = pd.read_csv('bankcsv_file.csv')

# pivot the dataframe to reshape it with company names as columns and sentimental scores as rows
pivoted_df = df.pivot(index= None, columns='Company Name', values='Sentiment Score')
df.fillna(0, inplace=True)


# save the pivoted dataframe to a new csv file
pivoted_df.to_csv('pivoted_file.csv')

# %%
print(pivoted_df)

# %%
pivoted_df

# %%
pivoted_df.to_excel('output01.xlsx', index=False)

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30))
ax = sns.heatmap(pivoted_df.corr(), annot=True)
plt.savefig("heatmap1.png")
plt.show()

# %%
pivoted_df
pivoted_df.to_csv('pivoted_file.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('output01.xlsx')

# %%
data

# %%
company_names = data.columns.tolist()

# %%
for company_name in company_names:
    scores = data[company_name].tolist()
    x_values = range(1, len(scores)+1)
    plt.bar(x_values, scores)
    plt.title(company_name)
    plt.xlabel('Score number')
    plt.ylabel('Score')
    plt.xlim([1, len(scores)])
    plt.ylim([min(scores), max(scores)])
    plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming your data is stored in a DataFrame called 'data'
company_names = data.columns.tolist()

# Plotting sentiment scores of two companies against each other
company1 = 'State Bank of India'
company2 = 'AU Small Finance Bank Limited'

plt.bar(data[company1], data[company2])
plt.xlabel(company1)
plt.ylabel(company2)
plt.title(f"{company1} vs {company2}")
plt.show()

# %%
import numpy as np

# Create arrays of different lengths
x1 = np.array([1, 2, 3])
y1 = np.array([4, 5, 6, 7])
x2 = np.array([1, 2])
y2 = np.array([3, 4, 5])

# Find the maximum length of all arrays
max_len = max(len(x1), len(y1), len(x2), len(y2))

# Pad the shorter arrays with NaN values
x1 = np.pad(x1, (0, max_len - len(x1)), mode='constant', constant_values=np.nan)
y1 = np.pad(y1, (0, max_len - len(y1)), mode='constant', constant_values=np.nan)
x2 = np.pad(x2, (0, max_len - len(x2)), mode='constant', constant_values=np.nan)
y2 = np.pad(y2, (0, max_len - len(y2)), mode='constant', constant_values=np.nan)

# Plot the arrays
plt.bar(x1, y1)
plt.bar(x2, y2)
plt.show()

# %%
company_names = data.columns.tolist()

# Plotting sentiment scores of one company against all other companies
company = 'State Bank of India'
other_companies = [c for c in company_names if c != company]

company_scores = data[company].values
other_scores = data[other_companies].mean(axis=1).values

df = pd.DataFrame({
    'Company': [company] * len(company_scores) + other_companies,
    'Sentiment Score': list(company_scores) + list(other_scores)
})

ax = df.plot.bar(x='Company', y='Sentiment Score', rot=0)
ax.set_xlabel('')
ax.set_title(f"{company} vs All Other Companies")
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(sentiment_scores)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(np.cumsum(pca.explained_variance_ratio_))
ax.set_xlabel('Number of Components')
ax.set_ylabel('Cumulative Explained Variance')
ax.set_ylim([0, 1])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sentiment_scores = scaler.fit_transform(sentiment_scores)
plt.show()
pca = PCA()
pca.fit(sentiment_scores)
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(np.cumsum(pca.explained_variance_ratio_))
ax.set_xlabel('Number of Components')
ax.set_ylabel('Cumulative Explained Variance')
plt.show()
pca = PCA(n_components=chosen_number_of_components)
principal_components = pca.fit_transform(sentiment_scores)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sentiment_scores = scaler.fit_transform(sentiment_scores)

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(sentiment_scores)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
data = pd.read_excel('output01.xlsx')# replace with your dataset file name
company_names = data.columns
sentiment_scores = data.values

# %%
pca = PCA()
pca.fit(sentiment_scores)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
plt.bar(range(len(pca.explained_variance_ratio_)), pca.explained_variance_ratio_)
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.title('Scree Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fit the PCA model to the data
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(sentiment_scores)

# Get the loadings for the principal components
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)

# Plot the loading plot for the first two principal components
fig, ax = plt.subplots(figsize=(10,10))
for i, txt in enumerate(company_names):
    x = loadings[i, 0]
    y = loadings[i, 1]
    plt.scatter(x, y)
    
    plt.annotate(txt, (x, y), xytext=(5, 5), textcoords='offset points')
plt.xlim((-0.0009, 0.0009))
plt.ylim((-0.0009, 0.0009))
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

# Assuming your dataset is stored in a pandas DataFrame called "df"
# Get the features for the PCA
features = data.columns

# Create a PCA model with 3 components
pca = PCA(n_components=3)

# Fit the model to the data
pca.fit(data)

# Get the loadings for each feature
loadings = pca.components_.T

# Create a 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot each feature as a point in 3D space
for i, feature in enumerate(features):
    x = loadings[i, 0]
    y = loadings[i, 1]
    z = loadings[i, 2]
    ax.scatter(x, y, z, color='blue')
    ax.text(x, y, z, feature)

# Set the axis labels and title
plt.xlim((-0.008, 0.008))
plt.ylim((-0.008, 0.008))
ax.set_zlim((-0.008, 0.008))

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('PCA Loading Plot')

# Show the plot
plt.show()

# %%
print(loadings.shape)

# %%
company_names = data.columns
scores = data.values
for i in range(len(company_names)):
    plt.scatter(scores[:,i], [i]*len(scores), label=company_names[i], alpha=0.5)

plt.xlabel('Scores')
plt.yticks(range(len(company_names)), company_names)
plt.ylabel('Company')
plt.legend()
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
# show plot
plt.show()

# %%
company_names = data.columns[1:]
data = data.iloc[:, 1:].values

# Standardize the data
data_std = (data - np.mean(data, axis=0)) / np.std(data, axis=0)

# Perform PCA
pca = PCA(n_components=2)
loadings = pca.fit_transform(data_std)
loadings = loadings.T

# Create a scatter plot of the data points with the loadings as arrows
fig, ax = plt.subplots()
ax.scatter(loadings[0], loadings[1])

for i, txt in enumerate(company_names):
    ax.annotate(txt, (loadings[0][i], loadings[1][i]))

for i in range(data_std.shape[1]):
    ax.arrow(0, 0, pca.components_[0, i], pca.components_[1, i])
plt.xlim((-0.6, 0.8))
plt.ylim((-0.6, 0.6))    

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('2D Biplot of Company Scores')
plt.show()

# %%
data = pd.read_excel('output01.xlsx')# replace with your dataset file name
company_names = data.columns
sentiment_scores = data.values

# %%
# create a list of colors for each company name
colors = ['red', 'blue', 'green', 'orange', 'purple', 'yellow', 'black', 'brown', 'pink', 'gray', 'cyan', 'magenta', 'olive', 'navy', 'teal', 'lime', 'maroon', 'gold', 'indigo', 'tomato', 'orchid', 'lavender', 'salmon', 'turquoise', 'khaki']

# plot the scores and loadings
for i, company in enumerate(company_names):
    x = scores[i, 0]
    y = scores[i, 1]
    plt.scatter(x, y, color=colors[i])
    plt.annotate(company, (x, y), xytext=(5, 5), textcoords='offset points')

    x = loadings[i, 0]
    y = loadings[i, 1]
    plt.arrow(0, 0, x, y, head_width=0.05, head_length=0.1, fc=colors[i], ec=colors[i])
    plt.annotate(sentiment_scores.columns[i], (x, y), xytext=(5, 5), textcoords='offset points')

# add legend
plt.legend(company_names)

# %%
data = pd.read_excel('output01 - Copy.xlsx')

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(30,30))
ax = sns.heatmap(data.corr(), annot=True)
plt.savefig("heatmap1.png")
plt.show()

# %%
data
import numpy as np

# %%
company_names = data.columns
sentiment_scores = data.values

# Replace NaN values with 0
sentiment_scores = np.nan_to_num(sentiment_scores)

pca = PCA()
pca.fit(sentiment_scores)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
plt.bar(range(len(pca.explained_variance_ratio_)), pca.explained_variance_ratio_)
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.title('Scree Plot')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Replace NaN values with 0
sentiment_scores = np.nan_to_num(data.values)

# Fit PCA model
pca = PCA()
pca.fit(sentiment_scores)

# Obtain the principal components
PC1 = pca.components_[0]
PC2 = pca.components_[1]

# Create a scatter plot with company names as labels
fig, ax = plt.subplots()
ax.scatter(PC1, PC2)
for i, company in enumerate(data.columns):
    ax.annotate(company, (PC1[i], PC2[i]))
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Replace NaN values with 0
sentiment_scores = np.nan_to_num(data.values)

# Fit PCA model
pca = PCA()
pca.fit(sentiment_scores)

# Obtain the principal components
PC1 = pca.components_[0]
PC2 = pca.components_[1]

# Create a scatter plot with company names as labels
fig, ax = plt.subplots()
ax.scatter(PC1, PC2)
for i, company in enumerate(data.columns):
    ax.annotate(company, (PC1[i], PC2[i]))
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# load the data


# extract the company names and sentiment scores
company_names = data.columns
sentiment_scores = data.values

# remove NaN values
sentiment_scores = np.nan_to_num(sentiment_scores)

# perform PCA
pca = PCA(n_components=25)
pca.fit(sentiment_scores)
PC1, PC2, PC3 = pca.components_

# flatten the sentiment_scores array to 1D
sentiment_scores_reshaped = sentiment_scores.ravel()

# create a 3D scatter plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(PC1, PC2, PC3, c=sentiment_scores_reshaped, cmap='coolwarm', s=100*abs(sentiment_scores_reshaped))

# add a colorbar
plt.colorbar(scatter)

# set the labels and title
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('3D PCA Loading Plot')

# show the plot
plt.show()





# Add colorbar legend
plt.colorbar()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13248\3142762882.py in <module>
#      18 pca = PCA(n_components=25)
#      19 pca.fit(sentiment_scores)
# ---> 20 PC1, PC2, PC3 = pca.components_
#      21
#      22 # flatten the sentiment_scores array to 1D
#
# ValueError: too many values to unpack (expected 3)

# %%
print(sentiment_scores.shape)

# %%
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

# Assuming your dataset is stored in a pandas DataFrame called "df"
# Get the features for the PCA
features = data.columns
# remove NaN values
sentiment_scores = np.nan_to_num(sentiment_scores)
# Create a PCA model with 3 components
pca = PCA(n_components=3)

# Fit the model to the data
pca.fit(sentiment_scores)

# Get the loadings for each feature
loadings = pca.components_.T

# Create a 3D plot
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot each feature as a point in 3D space
for i, feature in enumerate(features):
    x = loadings[i, 0]
    y = loadings[i, 1]
    z = loadings[i, 2]
    ax.scatter(x, y, z, color='blue')
    ax.text(x, y, z, feature)

# Set the axis labels and title
plt.xlim((-0.6, 0.4))
plt.ylim((-0.6, 0.4))
ax.set_zlim((-0.6, 0.4))

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
# Out:
# Text(0.5, 0.5, 'PC2')

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load data from Excel file
data = pd.read_excel('output01 - Copy.xlsx')
data.fillna(0, inplace=True)

# Remove rows with NaN or infinite values



# Get the feature names and data values
features = data.columns[1:]
data = data.iloc[:, 0:25].values

# Standardize the data
data_std = (data - np.mean(data, axis=0)) / np.std(data, axis=0)

# Perform PCA
pca = PCA(n_components=2)
loadings = pca.fit_transform(data_std)
loadings = loadings.T

# Create a scatter plot of the data points with the loadings as arrows
fig, ax = plt.subplots()
ax.scatter(loadings[0], loadings[1])

for i, txt in enumerate(features):
    ax.annotate(txt, (loadings[0][i], loadings[1][i]))

for i in range(data_std.shape[1]):
    ax.arrow(0, 0, pca.components_[0, i], pca.components_[1, i])
plt.xlim((-0.6, 0.6))
plt.ylim((-0.6, 0.6))    

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('2D Biplot of Company Scores')
plt.show()

# %%
data = pd.read_excel('output01 - Copy.xlsx')

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
data = data.iloc[:, 25:].values

# Standardize the data
data_std = (data - np.mean(data, axis=0)) / np.std(data, axis=0)

# Perform PCA
pca = PCA(n_components=2)
loadings = pca.fit_transform(data_std)
loadings = loadings.T

# Create a scatter plot of the data points with the loadings as arrows
fig, ax = plt.subplots()
ax.scatter(loadings[0], loadings[1])

for i, txt in enumerate(company_names):
    ax.annotate(txt, (loadings[0][i], loadings[1][i]))

for i in range(data_std.shape[1]):
    ax.arrow(0, 0, pca.components_[0, i], pca.components_[1, i])
plt.xlim((-0.6, 0.8))
plt.ylim((-0.6, 0.6))    

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('2D Biplot of Company Scores')
plt.show()

# %%
company_names = data.columns
scores = data.values
for i in range(len(company_names)):
    plt.scatter(scores[:,i], [i]*len(scores), label=company_names[i], alpha=0.5)

plt.xlabel('Scores')
plt.yticks(range(len(company_names)), company_names)
plt.ylabel('Company')
plt.legend()
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
# show plot
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from bioinfokit.analys import get_data
from bioinfokit.visuz import cluster

# %%
X = data.iloc[:, 0:25]

# %%
target = data.columns.to_numpy()

# %%
X.head(2)

# %%
X_st =  StandardScaler().fit_transform(X)
pca_out = PCA().fit(X_st)

# %%
data = pd.read_excel('output01 - Copy.xlsx')
data.fillna(0, inplace=True)

# %%
loadings = pca_out.components_

# %%
loadings

# %%
pca_out.explained_variance_

# %%
pca_scores = PCA().fit_transform(X_st)

# %%
pca_out = PCA().fit(X_st)
var1 = round(pca_out.explained_variance_ratio_[0]*100, 2)
var2 = round(pca_out.explained_variance_ratio_[1]*100, 2)

# %%
pca_scores = PCA().fit_transform(X_st)
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
    var2=round(pca_out.explained_variance_ratio_[1]*100, 2),)

# %%
X_st.shape

# %%
pip install cluster

# %%
pca_scores

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from cluster import biplot

# Load data
data = np.loadtxt('data.txt', delimiter=',')

# Separate X and target variables
X = data[:, :25]
col_names = data.dtype.names[:25]

# Standardize the data
X_st = (X - X.mean()) / X.std()

# Perform PCA and obtain scores
pca_scores = PCA().fit_transform(X_st)

# Obtain loadings
loadings = PCA().components_.T

# Obtain explained variance ratios
pca_out = PCA().fit(X_st)
var1 = round(pca_out.explained_variance_ratio_[0]*100, 2)
var2 = round(pca_out.explained_variance_ratio_[1]*100, 2)

# Generate biplot
biplot(cscore=pca_scores, loadings=loadings, labels=col_names, var1=var1, var2=var2)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13248\2924606883.py in <module>
#       2 from sklearn.decomposition import PCA
#       3 import matplotlib.pyplot as plt
# ----> 4 from cluster import biplot
#       5
#       6 # Load data
#
# ImportError: cannot import name 'biplot' from 'cluster' (C:\Users\Lithish\Anaconda3\lib\site-packages\cluster\__init__.py)

# %%
pca_scores = PCA().fit_transform(df_st)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13248\322628409.py in <module>
# ----> 1 pca_scores = PCA().fit_transform(df_st)
#
# NameError: name 'df_st' is not defined
